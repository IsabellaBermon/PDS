# %% [markdown]
# # Ejemplo 1. Desplazamiento de Señales Periodicas y Aperiodicas.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Primero se va a hacer un ejemplo de desplazamiento de una señal no periódica.

# %%
def desplazar_nper(secuencia, desplazamiento):
    # Toma el desplazamiento, y, mientras el contador sea menor a ese contadorvan a haber ceros,
    # luego de eso, se usa el mismo desplazamiento para agarrar los valores que se omitieron por la
    # sentencia IF.
    secuencia_despl = []
    for i in range(len(secuencia)):
        if (i < desplazamiento):
            secuencia_despl.append(0)
        else:
            secuencia_despl.append(secuencia[i-desplazamiento])
    return secuencia_despl

# %%
x1_n = [1,2,3,4,5]                      # Señal original
x1_n_despl = desplazar_nper(x1_n, 2)    # Señal desplazada

# Graficar señales desplazada y no desplazada
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.title('Señal original $x(n)$')
plt.stem(np.arange(len(x1_n)), x1_n)
plt.grid()
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')

plt.subplot(122)
plt.title('Señal desplazada en $x(n-a)$')
plt.stem(np.arange(len(x1_n_despl)), x1_n_despl)
plt.grid()
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')

plt.show()

# %% [markdown]
# Ahora, el desplazamiento de una señal periódica

# %%
def desplazar_per(secuencia, desplazamiento):
    # Mientras el contador sea menor al desplazamiento, se van a poner los ultimos valores de la
    # secuencia de primeros conservando el orden, luego se ponen los valores restantes omitidos por
    # la sentencia IF.
    secuencia_despl = []
    for i in range(len(secuencia)):
        if (i < desplazamiento):
            secuencia_despl.append(secuencia[len(secuencia)-desplazamiento+i])
        else:
            secuencia_despl.append(secuencia[i-desplazamiento])
    return secuencia_despl

# %%
x2_n = [1,2,3,4,5]                      # Señal original
x2_n_despl = desplazar_per(x1_n, 3)     # Señal desplazada

# Graficar señales desplazada y no desplazada
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.title('Señal original $x(n)$')
plt.stem(np.arange(len(x2_n)), x2_n)
plt.grid()
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')

plt.subplot(122)
plt.title('Señal desplazada en $x(n-a)$')
plt.stem(np.arange(len(x2_n_despl)), x2_n_despl)
plt.grid()
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')

plt.show()

# %% [markdown]
# # Ejemplo 1.2 Desplazamiento de Señales Periodicas y Aperiodicas usando librería numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

par = np.array([1, 2, 3, 4, 5]) # Señal original
par_periodica = np.tile(par, 3)  # Señal original repetida para notar periodicidad
par_periodica_desp = np.roll(par_periodica, 2)  # Señal desplazada n

# Graficar señales desplazada y no desplazada
plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.title('Señal par')
plt.stem(np.arange(len(par_periodica)), par_periodica)
plt.grid()
plt.xlabel('Muestras')
plt.ylabel('Amplitud')

plt.subplot(222)
plt.title('Señal par con desplazamiento n-2')
plt.stem(np.arange(len(par_periodica_desp)), par_periodica_desp)
plt.grid()
plt.xlabel('Muestras')
plt.ylabel('Amplitud')

plt.tight_layout()
plt.show()

# %%
impar_periodica_desp = np.array([1, 2, 3, 4]) # Señal original
impar_periodica = np.tile(x_odd, 4)  # Señal original repetida para notar periodicidad
impar_periodica_desp = np.roll(x_odd_periodic, 1)  # Señal desplazada n

# Graficar señales desplazada y no desplazada
plt.figure(figsize=(12, 8))
plt.subplot(223)
plt.title('Señal impar')
plt.stem(np.arange(len(impar_periodica)), impar_periodica)
plt.grid()
plt.xlabel('Muestras')
plt.ylabel('Amplitud')

plt.subplot(224)
plt.title('Señal impar con desplazamiento n-2')
plt.stem(np.arange(len(impar_periodica_desp)), impar_periodica_desp)
plt.grid()
plt.xlabel('Muestras')
plt.ylabel('Amplitud')

plt.tight_layout()
plt.show()
